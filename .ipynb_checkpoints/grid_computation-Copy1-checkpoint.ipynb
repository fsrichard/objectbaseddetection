# %%
import datacube
import xarray as xr
from joblib import load
import matplotlib.pyplot as plt
from datacube.utils.cog import write_cog
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import json
import pickle

from dea_tools.datahandling import load_ard
from dea_tools.bandindices import calculate_indices
from dea_tools.dask import create_local_dask_cluster
from dea_tools.plotting import rgb, display_map
from dea_tools.classification import predict_xr
from dea_tools.spatial import xr_rasterize

from datacube.utils import geometry
from datacube.utils.cog import write_cog

from odc.io.cgroups import get_cpu_quota
from odc.algo import geomedian_with_mads, xr_geomedian

# %%
ncpus = round(get_cpu_quota())
print("ncpus = " + str(ncpus))

client = create_local_dask_cluster()
# Out:
# ncpus = 0
# 2022-10-04 01:56:42,708 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-32u24zut', purging
# <Client: 'tcp://127.0.0.1:38329' processes=1 threads=8, memory=25.21 GiB>

# %%
# Choose file containing test areas and load
districts_file = "swk_bahagian/Division_boundary.shp"
districts_gdf = gpd.read_file(districts_file)

# Set results path
results_path = "figures/"

districts_gdf
# Out:
#                 LAYER       NAME     SHAPE_Leng          KM2     Shape_Le_1  \
# 0   Unknown Area Type   SRI AMAN  470305.017680  2324.000000  470298.275942
# 1   Unknown Area Type       SIBU  252444.728992  2230.000000  252441.432272
# 2   Unknown Area Type  SAMARAHAN  123475.382327   407.000000  123475.789412
# 3   Unknown Area Type     SERIAN  258512.211373  1749.255327  258510.531211
# 4   Unknown Area Type    SARIKEI  187428.671715   985.000000  187428.670401
# 5   Unknown Area Type    BINTULU  296210.063448  1991.000000  296210.063395
# 6   Unknown Area Type      KAPIT  493752.612989  3973.000000  493755.031503
# 7   Unknown Area Type      MUKAH  273420.724505  2536.000000  273420.850918
# 8   Unknown Area Type     BETONG  224890.052659  1547.000000  224751.345544
# 9   Unknown Area Type       MIRI  179372.707174  5143.000000  179372.707174
# 10  Unknown Area Type    LIMBANG  476768.055001  3978.000000  476763.285518
# 11  Unknown Area Type    KUCHING  378568.845373  1498.388001  378570.548459
#
#       Shape_Le_2    Shape_Area  Positif   PUI  Kematian CLOSED BORDER_STY  \
# 0   4.929813e+05  5.525035e+09      1.0   0.0       0.0    YES      Solid
# 1   7.215412e+05  8.346393e+09      4.0   2.0       0.0    YES      Solid
# 2   3.588758e+05  2.893719e+09     34.0  11.0       3.0    YES      Solid
# 3   2.997779e+05  2.453942e+09      5.0  19.0       0.0    YES      Solid
# 4   4.540618e+05  4.336811e+09      6.0   0.0       0.0    YES      Solid
# 5   8.627576e+05  1.221241e+10      5.0   4.0       0.0    YES      Solid
# 6   1.462950e+06  3.868118e+10      0.0   0.0       0.0    YES      Solid
# 7   5.975794e+05  6.969108e+09      2.0   0.0       0.0    YES      Solid
# 8   3.500982e+05  4.199905e+09     11.0  27.0       0.0    YES      Solid
# 9   1.051237e+06  2.681056e+10     13.0  12.0       1.0    YES      Solid
# 10  7.598058e+05  7.655016e+09      8.0   0.0       1.0    YES      Solid
# 11  5.721032e+05  4.108733e+09    150.0  55.0       4.0    YES      Solid
#
#     BORDER_COL  BORDER_WID FILL_STYLE                    LABEL_POS  FONT_SIZE  \
# 0   RGB(0,0,0)           1    No Fill  111.6320469333,1.2677673284         12
# 1   RGB(0,0,0)           1    No Fill  112.2423789129,2.2604103842         12
# 2   RGB(0,0,0)           1    No Fill  110.8603218599,1.2828038168         12
# 3   RGB(0,0,0)           1    No Fill  110.5401468453,1.1352557431         12
# 4   RGB(0,0,0)           1    No Fill  111.7064307920,1.9384331774         12
# 5   RGB(0,0,0)           1    No Fill  113.2481934884,2.9289797066         12
# 6   RGB(0,0,0)           1    No Fill  113.9810500729,2.2874239215         12
# 7   RGB(0,0,0)           1    No Fill  111.7990769684,2.5887497577         12
# 8   RGB(0,0,0)           1    No Fill  111.3271188370,1.6703303087         12
# 9   RGB(0,0,0)           1    No Fill  114.5292535753,3.6339974555         12
# 10  RGB(0,0,0)           1    No Fill  115.2272085801,4.1419532978         12
# 11  RGB(0,0,0)           1    No Fill  110.1044072359,1.5649386149         12
#
#     FONT_COLOR  FONT_CHARS                                           geometry
# 0   RGB(0,0,0)           1  POLYGON ((111.82349 1.58632, 111.82548 1.58588...
# 1   RGB(0,0,0)           1  POLYGON ((112.58422 2.84578, 112.58641 2.84510...
# 2   RGB(0,0,0)           1  POLYGON ((110.60497 1.59626, 110.60516 1.59621...
# 3   RGB(0,0,0)           1  POLYGON ((110.41944 1.41626, 110.42020 1.41462...
# 4   RGB(0,0,0)           1  POLYGON ((111.54579 2.36337, 111.54603 2.36333...
# 5   RGB(0,0,0)           1  POLYGON ((113.46243 3.65452, 113.46260 3.65280...
# 6   RGB(0,0,0)           1  POLYGON ((114.17562 3.35716, 114.17587 3.35710...
# 7   RGB(0,0,0)           1  POLYGON ((112.72257 3.04363, 112.72258 3.04355...
# 8   RGB(0,0,0)           1  POLYGON ((111.20581 2.07041, 111.20751 2.06912...
# 9   RGB(0,0,0)           1  POLYGON ((114.19831 4.53133, 114.19897 4.53026...
# 10  RGB(0,0,0)           1  POLYGON ((115.57858 4.98999, 115.57876 4.98970...
# 11  RGB(0,0,0)           1  POLYGON ((109.65342 2.04060, 109.65345 2.04060...

# %%
# plot to see the division boundaries
districts_gdf.plot()
# Out:
# <AxesSubplot:>

# %%
from datacube.utils import geometry
geom = geometry.Geometry(geom=districts_gdf.iloc[0].geometry,
                         crs=districts_gdf.crs)

# %%
dc = datacube.Datacube(app='Using_load_ard')

# %%
# %%time

from deafrica_tools.datahandling import load_ard

# Create a reusable query
query = {
    'time': ('2019-01', '2019-12'),
    'measurements': ['B02', 'B03', 'B04', 'nir'],
    'output_crs': 'epsg:6933',
    'resolution': (-10, 10),
    'group_by': 'solar_day',
    'dask_chunks': {"x": 2000, "y": 2000}
}

# Load available data from S2
s2 = load_ard(dc=dc, geopolygon=geom,
              products=['s2_l2a'],
              **query)

# Print output data
s2
# Out:
# Using pixel quality parameters for Sentinel 2
# Finding datasets
#     s2_l2a
# /home/jovyan/virtenvs/odcgeeenv/lib/python3.8/site-packages/datacube/drivers/postgres/_api.py:564: SAWarning: Class CommonTimestamp will not make use of SQL compilation caching as it does not set the 'inherit_cache' attribute to ``True``.  This can have significant performance implications including some performance degradations in comparison to prior SQLAlchemy versions.  Set this attribute to True if this object can make use of the cache key generated by the superclass.  Alternatively, this attribute may be set to False which will disable this warning. (Background on this error at: https://sqlalche.me/e/14/cprf)
#   return self._connection.execute(select_query)
# /home/jovyan/virtenvs/odcgeeenv/lib/python3.8/site-packages/datacube/drivers/postgres/_api.py:564: SAWarning: Class Float8Range will not make use of SQL compilation caching as it does not set the 'inherit_cache' attribute to ``True``.  This can have significant performance implications including some performance degradations in comparison to prior SQLAlchemy versions.  Set this attribute to True if this object can make use of the cache key generated by the superclass.  Alternatively, this attribute may be set to False which will disable this warning. (Background on this error at: https://sqlalche.me/e/14/cprf)
#   return self._connection.execute(select_query)
# Applying pixel quality/cloud mask
# Returning 146 time steps as a dask array
# CPU times: user 1.55 s, sys: 56.9 ms, total: 1.61 s
# Wall time: 1.69 s
# <xarray.Dataset>
# Dimensions:      (time: 146, y: 8178, x: 12444)
# Coordinates:
#   * time         (time) datetime64[ns] 2019-01-02T03:07:23 ... 2019-12-30T02:...
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
# Data variables:
#     B02          (time, y, x) float32 dask.array<chunksize=(1, 2000, 2000), meta=np.ndarray>
#     B03          (time, y, x) float32 dask.array<chunksize=(1, 2000, 2000), meta=np.ndarray>
#     B04          (time, y, x) float32 dask.array<chunksize=(1, 2000, 2000), meta=np.ndarray>
#     nir          (time, y, x) float32 dask.array<chunksize=(1, 2000, 2000), meta=np.ndarray>
# Attributes:
#     crs:           epsg:6933
#     grid_mapping:  spatial_ref

# %%
dcf = s2.to_array(dim="variable")

dcf
# Out:
# <xarray.DataArray 'stack-a57a08a9b2308ed082ddd96a02dada81' (variable: 4,
#                                                             time: 146, y: 8178,
#                                                             x: 12444)>
# dask.array<stack, shape=(4, 146, 8178, 12444), dtype=float32, chunksize=(1, 1, 2000, 2000), chunktype=numpy.ndarray>
# Coordinates:
#   * time         (time) datetime64[ns] 2019-01-02T03:07:23 ... 2019-12-30T02:...
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
#   * variable     (variable) <U3 'B02' 'B03' 'B04' 'nir'
# Attributes:
#     crs:           epsg:6933
#     grid_mapping:  spatial_ref

# %%
median = dcf.to_dataset(dim="variable") #important to explicitly define dim

median
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 146, y: 8178, x: 12444)
# Coordinates:
#   * time         (time) datetime64[ns] 2019-01-02T03:07:23 ... 2019-12-30T02:...
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
# Data variables:
#     B02          (time, y, x) float32 dask.array<chunksize=(1, 2000, 2000), meta=np.ndarray>
#     B03          (time, y, x) float32 dask.array<chunksize=(1, 2000, 2000), meta=np.ndarray>
#     B04          (time, y, x) float32 dask.array<chunksize=(1, 2000, 2000), meta=np.ndarray>
#     nir          (time, y, x) float32 dask.array<chunksize=(1, 2000, 2000), meta=np.ndarray>
# Attributes:
#     crs:           epsg:6933
#     grid_mapping:  spatial_ref

# %%
# Compute a single median from all data
ds_median = median.median('time')

ds_median
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8178, x: 12444)
# Coordinates:
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
# Data variables:
#     B02          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B03          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B04          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     nir          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>

# %%
data_meanarray = ds_median.to_array()
data_meanarray
# Out:
# <xarray.DataArray 'stack-eca10f7947a87b3e2f85b2303b3a4c3a' (variable: 4,
#                                                             y: 8178, x: 12444)>
# dask.array<stack, shape=(4, 8178, 12444), dtype=float32, chunksize=(1, 400, 400), chunktype=numpy.ndarray>
# Coordinates:
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
#   * variable     (variable) <U3 'B02' 'B03' 'B04' 'nir'

# %%
data = data_meanarray.to_dataset(dim='variable')  
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8178, x: 12444)
# Coordinates:
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
# Data variables:
#     B02          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B03          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B04          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     nir          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>

# %%
#vegetation indices 

# Calculate the NDVI
band_diff = data.nir - data.B04
band_sum = data.nir + data.B04
ndvi = band_diff / band_sum

#layer ndvi to the data
data['ndvi']=ndvi
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8178, x: 12444)
# Coordinates:
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
# Data variables:
#     B02          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B03          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B04          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     nir          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     ndvi         (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>

# %%
#EVI layer
#sample from earth engine 

"""var evi = comp.expression(
    '2.5 * ((NIR - RED) / (NIR + 6 * RED - 7.5 * BLUE + 1))', {
      'NIR': comp.select('B5'),
      'RED': comp.select('B4'),
      'BLUE': comp.select('B2')
}); """
evi = (2.5 * ((data.nir - data.B04) / (data.nir + 6 * data.B04 - 7.5 * data.B02 +1)))

data['evi']=evi
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8178, x: 12444)
# Coordinates:
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
# Data variables:
#     B02          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B03          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B04          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     nir          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     ndvi         (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     evi          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>

# %%
#In Landsat 8, SAVI = ((Band 5 – Band 4) / (Band 5 + Band 4 + 0.5)) * (1.5)
#from GEE, L8
"""var savi = comp.expression(
    '((B5 - B4) / (B5 + B4 + 0.5)) * (1.5)',{
      'B5': comp.select('B5'),
      'B4': comp.select('B4')
      """

savi = (((data.nir - data.B04)/(data.nir + data.B04 + 0.5)) * 1.5) 
data['savi']= savi 
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8178, x: 12444)
# Coordinates:
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
# Data variables:
#     B02          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B03          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B04          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     nir          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     ndvi         (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     evi          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     savi         (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>

# %%
# GCI 
#from GEE

"""var gci = comp.expression(
    'NIR / (B3 - 1)',{
      'NIR': comp.select('B5'),
      'B3': comp.select('B3')
});"""

gci = ((data.nir / data.B03) - 1) 

data['gci']= gci
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8178, x: 12444)
# Coordinates:
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
# Data variables:
#     B02          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B03          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B04          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     nir          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     ndvi         (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     evi          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     savi         (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     gci          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>

# %%
# Rename some of the bands to match the bands during the model development. 
data['B2'] = data['B02']  
data = data.drop(['B02'])

# %%
data['B3'] = data['B03']  
data = data.drop(['B03'])

# %%
data['B4'] = data['B04']  
data = data.drop(['B04'])

# %%
data['B8'] = data['nir']  
data = data.drop(['nir']) 

data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8178, x: 12444)
# Coordinates:
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
# Data variables:
#     ndvi         (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     evi          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     savi         (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     gci          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B2           (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B3           (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B4           (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B8           (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>

# %%
#Rearrange to match the model's features.
data = data[['B2', 'B3', 'B4', 'B8', 'evi', 'gci', 'ndvi', 'savi']]  

data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8178, x: 12444)
# Coordinates:
#   * y            (y) float64 2.026e+05 2.026e+05 ... 1.208e+05 1.208e+05
#   * x            (x) float64 1.07e+07 1.07e+07 1.07e+07 ... 1.083e+07 1.083e+07
#     spatial_ref  int32 6933
# Data variables:
#     B2           (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B3           (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B4           (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     B8           (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     evi          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     gci          (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     ndvi         (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>
#     savi         (y, x) float32 dask.array<chunksize=(400, 400), meta=np.ndarray>

# %%
# Import the trained model. 
import joblib
model = joblib.load("model/HGBtuned_S2OP.pkl")

print(model)
# Out:
# HistGradientBoostingClassifier(early_stopping=False, l2_regularization=0.1,
#                                learning_rate=0.08, max_depth=85, max_iter=150,
#                                max_leaf_nodes=19)

# %%
# Choose file containing test areas and load
districts_file = "swk_bahagian/Division_boundary.shp"
districts_gdf = gpd.read_file(districts_file)

# Set results path
results_path = "figures/"

districts_gdf
# Out:
#                 LAYER       NAME     SHAPE_Leng          KM2     Shape_Le_1  \
# 0   Unknown Area Type   SRI AMAN  470305.017680  2324.000000  470298.275942
# 1   Unknown Area Type       SIBU  252444.728992  2230.000000  252441.432272
# 2   Unknown Area Type  SAMARAHAN  123475.382327   407.000000  123475.789412
# 3   Unknown Area Type     SERIAN  258512.211373  1749.255327  258510.531211
# 4   Unknown Area Type    SARIKEI  187428.671715   985.000000  187428.670401
# 5   Unknown Area Type    BINTULU  296210.063448  1991.000000  296210.063395
# 6   Unknown Area Type      KAPIT  493752.612989  3973.000000  493755.031503
# 7   Unknown Area Type      MUKAH  273420.724505  2536.000000  273420.850918
# 8   Unknown Area Type     BETONG  224890.052659  1547.000000  224751.345544
# 9   Unknown Area Type       MIRI  179372.707174  5143.000000  179372.707174
# 10  Unknown Area Type    LIMBANG  476768.055001  3978.000000  476763.285518
# 11  Unknown Area Type    KUCHING  378568.845373  1498.388001  378570.548459
#
#       Shape_Le_2    Shape_Area  Positif   PUI  Kematian CLOSED BORDER_STY  \
# 0   4.929813e+05  5.525035e+09      1.0   0.0       0.0    YES      Solid
# 1   7.215412e+05  8.346393e+09      4.0   2.0       0.0    YES      Solid
# 2   3.588758e+05  2.893719e+09     34.0  11.0       3.0    YES      Solid
# 3   2.997779e+05  2.453942e+09      5.0  19.0       0.0    YES      Solid
# 4   4.540618e+05  4.336811e+09      6.0   0.0       0.0    YES      Solid
# 5   8.627576e+05  1.221241e+10      5.0   4.0       0.0    YES      Solid
# 6   1.462950e+06  3.868118e+10      0.0   0.0       0.0    YES      Solid
# 7   5.975794e+05  6.969108e+09      2.0   0.0       0.0    YES      Solid
# 8   3.500982e+05  4.199905e+09     11.0  27.0       0.0    YES      Solid
# 9   1.051237e+06  2.681056e+10     13.0  12.0       1.0    YES      Solid
# 10  7.598058e+05  7.655016e+09      8.0   0.0       1.0    YES      Solid
# 11  5.721032e+05  4.108733e+09    150.0  55.0       4.0    YES      Solid
#
#     BORDER_COL  BORDER_WID FILL_STYLE                    LABEL_POS  FONT_SIZE  \
# 0   RGB(0,0,0)           1    No Fill  111.6320469333,1.2677673284         12
# 1   RGB(0,0,0)           1    No Fill  112.2423789129,2.2604103842         12
# 2   RGB(0,0,0)           1    No Fill  110.8603218599,1.2828038168         12
# 3   RGB(0,0,0)           1    No Fill  110.5401468453,1.1352557431         12
# 4   RGB(0,0,0)           1    No Fill  111.7064307920,1.9384331774         12
# 5   RGB(0,0,0)           1    No Fill  113.2481934884,2.9289797066         12
# 6   RGB(0,0,0)           1    No Fill  113.9810500729,2.2874239215         12
# 7   RGB(0,0,0)           1    No Fill  111.7990769684,2.5887497577         12
# 8   RGB(0,0,0)           1    No Fill  111.3271188370,1.6703303087         12
# 9   RGB(0,0,0)           1    No Fill  114.5292535753,3.6339974555         12
# 10  RGB(0,0,0)           1    No Fill  115.2272085801,4.1419532978         12
# 11  RGB(0,0,0)           1    No Fill  110.1044072359,1.5649386149         12
#
#     FONT_COLOR  FONT_CHARS                                           geometry
# 0   RGB(0,0,0)           1  POLYGON ((111.82349 1.58632, 111.82548 1.58588...
# 1   RGB(0,0,0)           1  POLYGON ((112.58422 2.84578, 112.58641 2.84510...
# 2   RGB(0,0,0)           1  POLYGON ((110.60497 1.59626, 110.60516 1.59621...
# 3   RGB(0,0,0)           1  POLYGON ((110.41944 1.41626, 110.42020 1.41462...
# 4   RGB(0,0,0)           1  POLYGON ((111.54579 2.36337, 111.54603 2.36333...
# 5   RGB(0,0,0)           1  POLYGON ((113.46243 3.65452, 113.46260 3.65280...
# 6   RGB(0,0,0)           1  POLYGON ((114.17562 3.35716, 114.17587 3.35710...
# 7   RGB(0,0,0)           1  POLYGON ((112.72257 3.04363, 112.72258 3.04355...
# 8   RGB(0,0,0)           1  POLYGON ((111.20581 2.07041, 111.20751 2.06912...
# 9   RGB(0,0,0)           1  POLYGON ((114.19831 4.53133, 114.19897 4.53026...
# 10  RGB(0,0,0)           1  POLYGON ((115.57858 4.98999, 115.57876 4.98970...
# 11  RGB(0,0,0)           1  POLYGON ((109.65342 2.04060, 109.65345 2.04060...

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
# "UserWarning: X does not have valid feature names, but HistGradientBoostingClassifier was fitted with feature names"

# filter the shape files per district based on its ID 
area_of_interest_gdf = districts_gdf.iloc[[0]]
district_column = "KM2"

for index, district in area_of_interest_gdf.iterrows():
    
    # Set up geometry
    district_name = str(int(district[district_column]))
    print(f"Processing {district_name}")
    
    # Check if district has already been processed. If so, skip
    output_filename = f"{results_path}/district_{district_name}_oilpalmprediction.tif"
    if os.path.exists(output_filename):
        print("Completed; Skipping")
        continue

    # set up query based on district polygon
    geom = geometry.Geometry(geom=district.geometry, crs=area_of_interest_gdf.crs)
    query.update({"geopolygon": geom})

    #predict using the imported model
    predicted = predict_xr(model,
                           data.unify_chunks(),
                           #proba=True,
                           persist=True,
                           clean=True,
                           return_input=False
                          ).astype(float).persist()
    
    # Write to cog
    prediction_file = f"{results_path}/district_{district_name}_oilpalm_prediction.tif"
    print(f"    Writing predictions to {prediction_file}")
    write_cog(
        predicted.Predictions.compute(),
        fname=prediction_file,
        overwrite=True
    )
# Out:
# Processing 2324
# predicting...
#     Writing predictions to figures//district_2324_oilpalm_prediction.tif
# /env/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: divide by zero encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /env/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but HistGradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# /env/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: divide by zero encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /env/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but HistGradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# /env/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: divide by zero encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /env/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but HistGradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# /env/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: divide by zero encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 2022-10-04 02:43:34,192 - distributed.worker_memory - WARNING - gc.collect() took 1.003s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-10-04 02:47:42,929 - distributed.worker_memory - WARNING - gc.collect() took 1.005s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# /env/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but HistGradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# /env/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: divide by zero encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 2022-10-04 02:51:07,495 - distributed.worker_memory - WARNING - gc.collect() took 1.006s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-10-04 02:54:34,876 - distributed.worker_memory - WARNING - gc.collect() took 1.014s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-10-04 02:58:02,684 - distributed.worker_memory - WARNING - gc.collect() took 1.035s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# /env/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but HistGradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# 2022-10-04 03:01:37,694 - distributed.worker_memory - WARNING - gc.collect() took 1.025s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# /env/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: divide by zero encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /env/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but HistGradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# /env/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but HistGradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# 2022-10-04 03:12:28,000 - distributed.worker_memory - WARNING - gc.collect() took 1.114s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# /env/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: divide by zero encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 2022-10-04 03:16:40,571 - distributed.worker_memory - WARNING - gc.collect() took 1.246s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-10-04 03:20:28,344 - distributed.worker_memory - WARNING - gc.collect() took 1.283s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# /env/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but HistGradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# 2022-10-04 03:25:11,288 - distributed.worker_memory - WARNING - gc.collect() took 1.294s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# /env/lib/python3.8/site-packages/dask/core.py:119: RuntimeWarning: divide by zero encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 2022-10-04 03:30:35,649 - distributed.worker_memory - WARNING - gc.collect() took 1.331s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2022-10-04 03:35:17,809 - distributed.worker_memory - WARNING - gc.collect() took 1.368s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.

# %%
# ref:
# https://github.com/digitalearthafrica/crop-type/blob/main/2_Machine_learning/04_Create_area_maps.ipynb

# %%
# possibly need to load the tiff later as float64 image
